# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Supondo um problema de Classificação (Classe A e Classe B) e você tenha modelado a solução com k = 10 e v = 1. Como você interpretaria a resposta do modelo em relação às duas possíveis classes? <br><br><br>

# %% [markdown]
# $$f(x) = \frac{1}{\sqrt{2\pi\sigma^{2}}} exp \Big[ -\frac{1}{2}\Big(\frac{x-\mu}{\sigma}\Big)^{2} \Big], x \in (-\infty, \infty).$$
# <br>

# %% [markdown]
# 1. O que você faria caso desejasse minimizar concomitantemente as ocorrências de FP e FN?

# %% [markdown]
# 1. É viável definir uma interpretação que minimize a ocorrência apenas de FP ou FN? Como?

# %% [markdown]
# 1. Caso na modelagem o projetista tenha optado por representar a solução do problema com v = 2, Como você interpretaria a resposta como sendo Classe A ou B?

# %% [markdown]
# 1. Uma boa prática, em problemas de classificação, é modelar o vetor de saída com uma dimensão igual ao número de classes. Nesses casos, como são definidas as respostas para cada classe? Que característica importante possui essa forma de representação?

# %% [markdown]
# 1. Suponha que você após o treino você aplique o modelo sobre o próprio conjunto de treino e obtenha como resposta a seguinte matriz de confusão:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class conf_matrix():
    def __init__(self,table,labels=''):
        import numpy as np
        
        self.table = table;
        self.labels = labels;
        if not labels:
            self.labels = [chr(65+x) for x in range(len(table))];
        
        
        self.acuracia   = np.sum(np.diag(self.table))/np.sum(self.table)
   
        if self.table.shape==(2,2):
            self.precisao_p = self.table[0,0]/np.sum(self.table[0,:])
            self.precisao_n = self.table[1,1]/np.sum(self.table[1,:])
            self.taxa_fp    = self.table[0,1]/np.sum(self.table[:,1])
            self.taxa_fn    = self.table[1,0]/np.sum(self.table[:,0])
    
    def summary(self,fields=[]):
        print('== Summary ==')
        
        if not fields:
            fields = [key for key in self.__dict__ if key not in ['labels','table']]
        
        for field in fields:
            print('+ {} field'.format(field))
            for col,label in enumerate(self.labels):
                temp = self.confusion(col)
                print('Label '+ label +' =',100*temp.acuracia)    
            
    
    def confusion(self,col):
        import numpy as np

        L   = np.concatenate((self.table[:col,:col],self.table[(col+1):,:col]))
        R   = np.concatenate((self.table[:col,(col+1):],self.table[(col+1):,(col+1):]))

        TN  = np.concatenate((L,R),axis=1)
        TN  = np.sum(TN)

        TP  = self.table[col,col]

        FP  = np.concatenate((self.table[:col,col],self.table[(col+1):,col]))
        FP  = np.sum(FP)

        FN  = np.concatenate((self.table[col,:col],self.table[col,(col+1):]))
        FN  = np.sum(FN)

        table = np.array([[TP,FP],[FN,TN]])
        
        return conf_matrix(table,['P'+self.labels[col],'N'+self.labels[col]])
    
    def __repr__(self):
        import numpy as np
        print('Labels:\t',self.labels)
        for key in self.__dict__:
            if key not in ['labels','table']:
                print(key,end=':\t')
                print(np.round(10000*self.__dict__[key])/100,'%')
        return ''

# %%
import numpy as np
ED = np.array([[70,5,0,3,1],[6,65,8,0,2],[3,10,75,1,0],[1,3,2,95,2],[5,0,1,1,100]])
ED = conf_matrix(ED)
np.sum(ED.table,axis=0)
# Out:
# array([ 85,  83,  86, 100, 105])

# %% [markdown]
# <b>a. Qual o tamanho do conjunto de treino e o número de exemplos de cada classe? <br> <br></b>
#
# 459, sendo 85 da classe A, 83 da classe B,  86 da classe C, 100 da classe D e 105 da classe E <br><br>

# %%
ED_mean = np.mean(np.sum(ED.table,axis=0))
ED_std  = np.std(np.sum(ED.table,axis=0))
print(ED_mean,ED_std,100*ED_std/ED_mean)
# Out:
# 91.8 8.93084542471 9.72858978726

# %% [markdown]
# <b>b. O treino usa as classes de forma balanceada? <br> <br></b>
# Sim, o número de amostra de cada classe variou entre 83 e 105 amostras, com número de amostra média de 91.8 e o desvio padrão 8.9. Sendo o desvio padrão 9.7% da média, na minha interpretação, afirmo que elas estão bem balanceadas.
# <br><br>

# %%
ED_n_acertos = np.sum(np.diag(ED.table))
ED_n         = np.sum(ED.table)
ED_acuracia  = 100*ED_n_acertos/ED_n

print(ED_n_acertos,ED_n,ED_acuracia)
# Out:
# 405 459 88.2352941176

# %% [markdown]
# <b>c. Qual a acurácia alcançada no treino? <br> <br></b>
# Sendo a acurácia a porcentagem de acertos, e sendo acertos quando a classe desejada é igual a classe estimada, ou seja a diagonal da matriz descrita. Das 459, 405 amostras foram classificadas de forma correta. Representando uma acurácia de 88.2%.
# <br><br>

# %%
for col,label in enumerate(ED.labels):
    a = ED.confusion(col)
    print('Label '+label+' =',100*a.acuracia)
# Out:
# Label A = 94.7712418301
# Label B = 92.5925925926
# Label C = 94.5533769063
# Label D = 97.1677559913
# Label E = 97.385620915

# %% [markdown]
# <b>d. Qual a classe melhor aprendida pelo modelo? <br> <br></b>
# A classe E foi a que obteve melhor aprendizado, tendo em vista que sua acurácia foi 97.38%.
# <br><br>

# %%
FullTable = conf_matrix(ED,2)
FullTable.table
# Out:
# array([[ 70,   5,   0,   3,   1],
#        [  6,  65,   8,   0,   2],
#        [  3,  10,  75,   1,   0],
#        [  1,   3,   2,  95,   2],
#        [  5,   0,   1,   1, 100]])

# %%
CTable = FullTable.confusion(2)
CTable
# Out:
# acuracia:	94.55 %
# precisao_p:	87.21 %
# precisao_n:	96.25 %
# taxa_fp:	2.97 %
# taxa_fn:	15.73 %

# %%
ED_C_desired = ED[:,2]
ED_C_estimated = ED[2,:]
N    = np.sum(ED)
C_id = 2;
C_N = np.sum(ED_C_desired)
C_FP = np.concatenate((ED_C_estimated[:C_id],ED_C_estimated[(C_id+1):]))
C_FN = np.concatenate((ED_C_desired[:C_id],ED_C_desired[(C_id+1):]))
print(C_N,N,np.sum(C_FP),np.sum(C_FN))
# Out:
# 86 459 14 11

# %%
CTable.acuracia
# Out:
# 0.94553376906318087

# %% [markdown]
# <b>e. Considerando a classe C, qual a taxa de FP e de FN? <br> <br></b>
#
# <br><br>

# %%
ED_A = ED[0,:]
ED_A_TruePositive = ED_A[0]
ED_A_FalsePositive = np.sum(ED_A[1:])

ED_A_precision = ED_A_TruePositive/(ED_A_TruePositive+ED_A_FalsePositive)
print(ED_A_TruePositive,ED_A_FalsePositive,ED_A_precision*100)
# Out:
# 70 9 88.6075949367

# %% [markdown]
# <b>f. Qual a precisão no reconhecimento da classe A? <br> <br></b>
# A precisão da classe A é igual a razão do número de verdadeiros positivos e a soma dos verdadeiros e falsos positivos para A. $\frac{70}{70 + 9} = 88.60\%$.
# <br><br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### A partir do arquivo de dados em anexo – DL_Teste02, cujo problema é o diagnóstico do câncer de mama, realize as operações a seguir e forneça os resultados obtidos

# %% [markdown]
# 1. Verifique os dados do problema e defina quem você quer considerar diagnóstico positivo e quemconsiderar negativo. <br> <br>
# 2. Considerando o número de exemplos disponíveis, que estratégia você usaria para definir os conjuntos de treino, validação e teste? <br> <br>
# 3. Fazendo de contas que a planilha contém apenas dados de teste e que a resposta do modelo foi a constante na coluna mais à direita, calcule a Matriz de Confusão, a acurácia e as taxas de falso positivo e falso negativo alcançadas. <br> <br>
# 4. Monte o gráfico e identifique, se possível, o valor do limiar de forma a reduzir, concomitantemente, os FPs e FNs. <br> <br>
# 5. Caso você precise interpretar a saída de forma a reduzir a ocorrência de FNs (diagnostica como boa uma pessoa com câncer), o que você faria? Mostre como ficaria a nova Matriz de Confusão, analise e explique as mudanças ocorridas.
